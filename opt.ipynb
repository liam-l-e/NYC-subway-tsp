# %% [markdown]
# ### Getting MTA station names, longitude, latitude

# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.ny.gov", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.ny.gov,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("39hk-dx4f", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

for index, row in results_df.iterrows():
    station_name = row['stop_name']
    longitude = row['gtfs_longitude']
    latitude = row['gtfs_latitude']
    station_id = row['gtfs_stop_id']

    # print(f"Station: {station_name}, Longitude: {longitude}, Latitude: {latitude}")

stations_df = results_df[['stop_name', 'gtfs_longitude', 'gtfs_latitude','gtfs_stop_id']]
print(stations_df)

stations_dict = stations_df.to_dict(orient='records')
print(stations_dict)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#                 stop_name gtfs_longitude gtfs_latitude gtfs_stop_id
# 0    Astoria-Ditmars Blvd     -73.912034     40.775036          R01
# 1            Astoria Blvd     -73.917843     40.770258          R03
# 2                   30 Av     -73.921479     40.766779          R04
# 3                Broadway     -73.925508      40.76182          R05
# 4                   36 Av     -73.929575     40.756804          R06
# ..                    ...            ...           ...          ...
# 491          Prince's Bay     -74.200064     40.525507          S15
# 492       Pleasant Plains     -74.217847      40.52241          S14
# 493       Richmond Valley     -74.229141     40.519631          S13
# 494           Tottenville     -74.251961     40.512764          S09
# 495           Arthur Kill     -74.242096     40.516578          S11
#
# [496 rows x 4 columns]
# [{'stop_name': 'Astoria-Ditmars Blvd', 'gtfs_longitude': '-73.912034', 'gtfs_latitude': '40.775036', 'gtfs_stop_id': 'R01'}, {'stop_name': 'Astoria Blvd', 'gtfs_longitude': '-73.917843', 'gtfs_latitude': '40.770258', 'gtfs_stop_id': 'R03'}, {'stop_name': '30 Av', 'gtfs_longitude': '-73.921479', 'gtfs_latitude': '40.766779', 'gtfs_stop_id': 'R04'}, {'stop_name': 'Broadway', 'gtfs_longitude': '-73.925508', 'gtfs_latitude': '40.76182', 'gtfs_stop_id': 'R05'}, {'stop_name': '36 Av', 'gtfs_longitude': '-73.929575', 'gtfs_latitude': '40.756804', 'gtfs_stop_id': 'R06'}, {'stop_name': '39 Av-Dutch Kills', 'gtfs_longitude': '-73.932755', 'gtfs_latitude': '40.752882', 'gtfs_stop_id': 'R08'}, {'stop_name': 'Lexington Av/59 St', 'gtfs_longitude': '-73.967258', 'gtfs_latitude': '40.76266', 'gtfs_stop_id': 'R11'}, {'stop_name': '5 Av/59 St', 'gtfs_longitude': '-73.973347', 'gtfs_latitude': '40.764811', 'gtfs_stop_id': 'R13'}, {'stop_name': '57 St-7 Av', 'gtfs_longitude': '-73.980658', 'gtfs_latitude': '40.764664', 'gtfs_stop_id': 'R14'}, {'stop_name': '49 St', 'gtfs_longitude': '-73.984139', 'gtfs_latitude': '40.759901', 'gtfs_stop_id': 'R15'}, {'stop_name': 'Times Sq-42 St', 'gtfs_longitude': '-73.986754', 'gtfs_latitude': '40.754672', 'gtfs_stop_id': 'R16'}, {'stop_name': '34 St-Herald Sq', 'gtfs_longitude': '-73.98795', 'gtfs_latitude': '40.749567', 'gtfs_stop_id': 'R17'}, {'stop_name': '28 St', 'gtfs_longitude': '-73.988691', 'gtfs_latitude': '40.745494', 'gtfs_stop_id': 'R18'}, {'stop_name': '23 St', 'gtfs_longitude': '-73.989344', 'gtfs_latitude': '40.741303', 'gtfs_stop_id': 'R19'}, {'stop_name': '14 St-Union Sq', 'gtfs_longitude': '-73.990568', 'gtfs_latitude': '40.735736', 'gtfs_stop_id': 'R20'}, {'stop_name': '8 St-NYU', 'gtfs_longitude': '-73.992629', 'gtfs_latitude': '40.730328', 'gtfs_stop_id': 'R21'}, {'stop_name': 'Prince St', 'gtfs_longitude': '-73.997702', 'gtfs_latitude': '40.724329', 'gtfs_stop_id': 'R22'}, {'stop_name': 'Canal St', 'gtfs_longitude': '-74.001775', 'gtfs_latitude': '40.719527', 'gtfs_stop_id': 'R23'}, {'stop_name': 'Canal St', 'gtfs_longitude': '-74.00046', 'gtfs_latitude': '40.718383', 'gtfs_stop_id': 'Q01'}, {'stop_name': 'City Hall', 'gtfs_longitude': '-74.006978', 'gtfs_latitude': '40.713282', 'gtfs_stop_id': 'R24'}, {'stop_name': 'Cortlandt St', 'gtfs_longitude': '-74.011029', 'gtfs_latitude': '40.710668', 'gtfs_stop_id': 'R25'}, {'stop_name': 'Rector St', 'gtfs_longitude': '-74.013342', 'gtfs_latitude': '40.70722', 'gtfs_stop_id': 'R26'}, {'stop_name': 'Whitehall St-South Ferry', 'gtfs_longitude': '-74.012994', 'gtfs_latitude': '40.703087', 'gtfs_stop_id': 'R27'}, {'stop_name': 'Court St', 'gtfs_longitude': '-73.991777', 'gtfs_latitude': '40.6941', 'gtfs_stop_id': 'R28'}, {'stop_name': 'Jay St-MetroTech', 'gtfs_longitude': '-73.985942', 'gtfs_latitude': '40.69218', 'gtfs_stop_id': 'R29'}, {'stop_name': 'DeKalb Av', 'gtfs_longitude': '-73.981824', 'gtfs_latitude': '40.690635', 'gtfs_stop_id': 'R30'}, {'stop_name': 'Atlantic Av-Barclays Ctr', 'gtfs_longitude': '-73.97881', 'gtfs_latitude': '40.683666', 'gtfs_stop_id': 'R31'}, {'stop_name': 'Union St', 'gtfs_longitude': '-73.98311', 'gtfs_latitude': '40.677316', 'gtfs_stop_id': 'R32'}, {'stop_name': '4 Av-9 St', 'gtfs_longitude': '-73.988302', 'gtfs_latitude': '40.670847', 'gtfs_stop_id': 'R33'}, {'stop_name': 'Prospect Av', 'gtfs_longitude': '-73.992872', 'gtfs_latitude': '40.665414', 'gtfs_stop_id': 'R34'}, {'stop_name': '25 St', 'gtfs_longitude': '-73.998091', 'gtfs_latitude': '40.660397', 'gtfs_stop_id': 'R35'}, {'stop_name': '36 St', 'gtfs_longitude': '-74.003549', 'gtfs_latitude': '40.655144', 'gtfs_stop_id': 'R36'}, {'stop_name': '45 St', 'gtfs_longitude': '-74.010006', 'gtfs_latitude': '40.648939', 'gtfs_stop_id': 'R39'}, {'stop_name': '53 St', 'gtfs_longitude': '-74.014034', 'gtfs_latitude': '40.645069', 'gtfs_stop_id': 'R40'}, {'stop_name': '59 St', 'gtfs_longitude': '-74.017881', 'gtfs_latitude': '40.641362', 'gtfs_stop_id': 'R41'}, {'stop_na ...

# %% [markdown]
# ### Optimize the path we take for objective of minimizing time traveled

# %%
import networkx as nx
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp
from scipy.optimize import minimize
import numpy as np


def haversine(lat1, lon1, lat2, lon2):
    """
    Calculates great circle distance in meters
    between two points on Earth in decimal degrees
    """
    lat1 = float(lat1)
    lon1 = float(lon1)
    lat2 = float(lat2)
    lon2 = float(lon2)
    R = 6371000
    phi1, phi2 = np.radians(lat1), np.radians(lat2)
    delta_phi = np.radians(lat2 - lat1)
    delta_lambda = np.radians(lon2 - lon1)
    a = np.sin(delta_phi/2.0) ** 2 + np.cos(phi1) * np.cos(phi2) * np.sin(delta_lambda/2.0) ** 2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
    meters = R*c
    miles = meters * 0.000621371  # Convert meters to miles
    return miles

def calculate_travel_time(distance):
    speed_mph = 17.4 # Average MTA subway speed
    travel_time_hours = distance / speed_mph
    return travel_time_hours * 60.0 # Hours to minutes

def create_distance_matrix(stations_data):
    num_stations = len(stations_data)
    stations_data = pd.DataFrame(stations_data)
    distance_matrix = np.zeros((num_stations,num_stations))

    for i in range(num_stations):
        # Access data using column names
        from_lat = stations_data.loc[i, 'gtfs_latitude']
        from_lng = stations_data.loc[i, 'gtfs_longitude']
        for j in range(num_stations):
            if i != j:
                to_lat = stations_data.loc[j, 'gtfs_latitude']
                to_lng = stations_data.loc[j, 'gtfs_longitude']
                distance = haversine(from_lat, from_lng, to_lat, to_lng)
                distance_matrix[i, j] = distance

    return distance_matrix
                
    return distance_matrix

def find_nearest_neighbor(distance_matrix,current_index,visited):
    min_distance = float('inf')
    nearest_index = -1
    for i, distance in enumerate(distance_matrix[current_index]):
        if i not in visited and distance < min_distance:
            min_distance = distance
            nearest_index = i
    return nearest_index

def solve_tsp_knn(stations_data):
    distance_matrix = create_distance_matrix(stations_data)
    num_stations = len(stations_data)

    start_index = 0
    visited = set()
    route = [start_index]
    visited.add(start_index)

    current_index = start_index
    while len(visited) < num_stations:
        nearest_index = find_nearest_neighbor(distance_matrix,current_index,visited)
        route.append(nearest_index)
        visited.add(nearest_index)
        current_index = nearest_index

    return route

def print_route_with_distances(stations_data,optimized_route):
    total_distance = 0
    total_time = 0
    output_lines = []
    output_lines.append("Optimized Route with Distances and Times in Miles and Minutes: ")

    for i in range(len(optimized_route)-1):
        from_station = stations_data[optimized_route[i]]['stop_name']
        to_station = stations_data[optimized_route[i+1]]['stop_name']

        from_lat, from_lng = stations_data[optimized_route[i]]['gtfs_latitude'],stations_data[optimized_route[i]]['gtfs_longitude']
        to_lat, to_lng = stations_data[optimized_route[i+1]]['gtfs_latitude'],stations_data[optimized_route[i+1]]['gtfs_longitude']

        distance = haversine(from_lat,from_lng,to_lat,to_lng)

        travel_time = calculate_travel_time(distance)

        total_distance += distance
        total_time += travel_time

        output_lines.append(f"From {from_station} to {to_station}: {distance:.2f} miles, {travel_time:.2f} minutes")

    output_lines.append(f"Total distance traveled: {total_distance:.2f} miles")
    output_lines.append(f"Total time traveled: {total_time:.2f} minutes")

    for line in output_lines:
        print(line)

def main_knn():
    stations_data_list = [dict(row) for _,row in pd.DataFrame(stations_df).iterrows()]
    optimized_route_indices = solve_tsp_knn(stations_data_list)
    print_route_with_distances(stations_data_list,optimized_route_indices)

if __name__ == "__main__":
    main_knn()
# Out:
# Optimized Route with Distances and Times in Miles and Minutes:
# From Astoria-Ditmars Blvd to Astoria Blvd: 0.45 miles, 1.55 minutes
# From Astoria Blvd to 30 Av: 0.31 miles, 1.06 minutes
# From 30 Av to Broadway: 0.40 miles, 1.39 minutes
# From Broadway to 36 Av: 0.41 miles, 1.40 minutes
# From 36 Av to 39 Av-Dutch Kills: 0.32 miles, 1.10 minutes
# From 39 Av-Dutch Kills to 36 St: 0.22 miles, 0.74 minutes
# From 36 St to Queens Plaza: 0.49 miles, 1.69 minutes
# From Queens Plaza to Queensboro Plaza: 0.19 miles, 0.66 minutes
# From Queensboro Plaza to Queensboro Plaza: 0.00 miles, 0.00 minutes
# From Queensboro Plaza to 21 St-Queensbridge: 0.29 miles, 0.99 minutes
# From 21 St-Queensbridge to Court Sq-23 St: 0.47 miles, 1.62 minutes
# From Court Sq-23 St to Court Sq: 0.07 miles, 0.24 minutes
# From Court Sq to Court Sq: 0.08 miles, 0.28 minutes
# From Court Sq to 21 St: 0.35 miles, 1.22 minutes
# From 21 St to Hunters Point Av: 0.13 miles, 0.46 minutes
# From Hunters Point Av to Vernon Blvd-Jackson Av: 0.25 miles, 0.85 minutes
# From Vernon Blvd-Jackson Av to Greenpoint Av: 0.78 miles, 2.69 minutes
# From Greenpoint Av to Nassau Av: 0.49 miles, 1.70 minutes
# From Nassau Av to Bedford Av: 0.59 miles, 2.02 minutes
# From Bedford Av to Lorimer St: 0.41 miles, 1.42 minutes
# From Lorimer St to Metropolitan Av: 0.11 miles, 0.37 minutes
# From Metropolitan Av to Graham Av: 0.40 miles, 1.40 minutes
# From Graham Av to Grand St: 0.25 miles, 0.88 minutes
# From Grand St to Montrose Av: 0.29 miles, 1.01 minutes
# From Montrose Av to Morgan Av: 0.37 miles, 1.27 minutes
# From Morgan Av to Jefferson St: 0.54 miles, 1.85 minutes
# From Jefferson St to DeKalb Av: 0.30 miles, 1.05 minutes
# From DeKalb Av to Knickerbocker Av: 0.36 miles, 1.25 minutes
# From Knickerbocker Av to Myrtle-Wyckoff Avs: 0.39 miles, 1.34 minutes
# From Myrtle-Wyckoff Avs to Myrtle-Wyckoff Avs: 0.05 miles, 0.17 minutes
# From Myrtle-Wyckoff Avs to Seneca Av: 0.29 miles, 0.99 minutes
# From Seneca Av to Forest Av: 0.27 miles, 0.93 minutes
# From Forest Av to Fresh Pond Rd: 0.40 miles, 1.37 minutes
# From Fresh Pond Rd to Middle Village-Metropolitan Av: 0.49 miles, 1.68 minutes
# From Middle Village-Metropolitan Av to Halsey St: 1.33 miles, 4.58 minutes
# From Halsey St to Wilson Av: 0.47 miles, 1.63 minutes
# From Wilson Av to Bushwick Av-Aberdeen St: 0.41 miles, 1.43 minutes
# From Bushwick Av-Aberdeen St to Broadway Junction: 0.23 miles, 0.80 minutes
# From Broadway Junction to Broadway Junction: 0.08 miles, 0.28 minutes
# From Broadway Junction to Broadway Junction: 0.11 miles, 0.40 minutes
# From Broadway Junction to Atlantic Av: 0.24 miles, 0.82 minutes
# From Atlantic Av to Alabama Av: 0.26 miles, 0.89 minutes
# From Alabama Av to Liberty Av: 0.20 miles, 0.70 minutes
# From Liberty Av to Van Siclen Av: 0.35 miles, 1.20 minutes
# From Van Siclen Av to Van Siclen Av: 0.37 miles, 1.29 minutes
# From Van Siclen Av to Cleveland St: 0.39 miles, 1.35 minutes
# From Cleveland St to Norwood Av: 0.26 miles, 0.90 minutes
# From Norwood Av to Crescent St: 0.35 miles, 1.21 minutes
# From Crescent St to Cypress Hills: 0.47 miles, 1.62 minutes
# From Cypress Hills to 75 St-Elderts Ln: 0.30 miles, 1.03 minutes
# From 75 St-Elderts Ln to 85 St-Forest Pkwy: 0.38 miles, 1.31 minutes
# From 85 St-Forest Pkwy to Woodhaven Blvd: 0.45 miles, 1.56 minutes
# From Woodhaven Blvd to 104 St: 0.39 miles, 1.35 minutes
# From 104 St to 111 St: 0.45 miles, 1.54 minutes
# From 111 St to 121 St: 0.47 miles, 1.63 minutes
# From 121 St to Jamaica-Van Wyck: 0.62 miles, 2.12 minutes
# From Jamaica-Van Wyck to Sutphin Blvd: 0.38 miles, 1.31 minutes
# From Sutphin Blvd to Sutphin Blvd-Archer Av-JFK Airport: 0.37 miles, 1.28 minutes
# From Sutphin Blvd-Archer Av-JFK Airport to Jamaica Center-Parsons/Archer: 0.38 miles, 1.30 minutes
# From Jamaica Center-Parsons/Archer to Parsons Blvd: 0.39 miles, 1.35 minutes
# From Parsons Blvd to 169 St: 0.55 miles, 1.89 minutes
# From 169 St to Jamaica-179 St: 0.53 miles, 1.84 minutes
# From Jamaica-179 St to Briarwood: 1.94 miles, 6.69 minutes
# From Briarwood to Kew Gardens-Union Tpke: 0.66 miles, 2.26 minutes
# From Kew Gardens-Union Tpke to 75 Av: 0.43 miles, 1.47 minutes
# From 75 Av to Forest Hills-71 Av: 0.44 miles, 1.53 minutes
# From Forest Hills-71 Av to 67 Av: 0.54 miles, 1.88 minutes
# From 67 Av to 63 Dr-Rego Park: 0.52 miles, 1.79 minutes
# From 63 Dr-Rego Park to Woodhaven Blvd: 0.46 miles, 1.58 minutes
# From Woodhaven Blvd to Grand Av-Newtown: 0.50 miles, 1.72 minutes
# From Grand Av-Newtown to Elmhurst Av: 0.45 miles, 1.56 minutes
# From Elmhurst Av to 82 St-Jackson Hts: 0.37 miles, 1.28 minutes
# From 82 St-Jackson Hts to 90 St-Elmhurst Av: 0.37 miles, 1.29 minutes
# From 90 St-Elmhurst Av to Junction Blvd: 0.37 miles, 1.29 minutes
# From Junction Blvd to 103 St-Corona Plaza: 0.36 miles, 1.24 minutes
# From 103 St-Corona Plaza to 111 St: 0.41 miles, 1.40 minutes
# From 111 St to Mets-Willets Point: 0.55 miles, 1.88 minutes
# From Mets-Willets Point to Flushing-Main St: 0.89 miles, 3.05 minutes
# From Flushing-Main St to 74 St-Broadway: 3.33 miles, 11.48 minutes
# From 74 St-Broadway to Jackson Hts-Roosevelt Av: 0.01 miles, 0.05 minutes
# From Jackson Hts-Roosevelt Av to 69 St: 0.27 miles, 0.92 minutes
# From 69 St to 65 St: 0.25 miles, 0.88 minutes
# From 65 St to 61 St-Woodside: 0.37 miles, 1.26 minutes
# From 61 St-Woodside to 52 St: 0.51 miles, 1.76 minutes
# From 52 St to 46 St-Bliss St: 0.32 miles, 1.09 minutes
# From 46 St-Bliss St to 40 St-Lowery St: 0.30 miles, 1.02 minutes
# From 40 St-Lowery St to 33 St-Rawson St: 0.37 miles, 1.27 minutes
# From 33 St-Rawson St to Steinway St: 1.00 miles, 3.46 minutes
# From Steinway St to 46 St: 0.39 miles, 1.34 minutes
# From 46 St to Northern Blvd: 0.45 miles, 1.55 minutes
# From Northern Blvd to Roosevelt Island: 2.51 miles, 8.66 minutes
# From Roosevelt Island to 72 St: 0.72 miles, 2.48 minutes
# From 72 St to 68 St-Hunter College: 0.29 miles, 1.00 minutes
# From 68 St-Hunter College to Lexington Av/63 St: 0.27 miles, 0.93 minutes
# From Lexington Av/63 St to Lexington Av/59 St: 0.15 miles, 0.51 minutes
# From Lexington Av/59 St to 59 St: 0.04 miles, 0.13 minutes
# From 59 St to 5 Av/59 St: 0.32 miles, 1.11 minutes
# From 5 Av/59 St to 57 St: 0.22 miles, 0.77 minutes
# From 57 St to 57 St-7 Av: 0.17 miles, 0.60 minutes
# From 57 St-7 Av to 7 Av: 0.13 miles, 0.46 minutes
# From 7 Av to 50 St: 0.14 miles, 0.48 minutes
# From 50 St to 50 St: 0.12 miles, 0.42 minutes
# From 50 St to 49 St: 0.20 miles, 0.69 minutes
# From 49 St to 47-50 Sts-Rockefeller Ctr: 0.17 miles, 0.59 minutes
# From 47-50 Sts-Rockefeller Ctr to Times Sq-42 St: 0.32 miles, 1.09 minutes
# From Times Sq-42 St to Times Sq-42 St: 0.08 miles, 0.28 minutes
# From Times Sq-42 St to Times Sq-42 St: 0.02 miles, 0.06 minutes
# From Times Sq-42 St to Times Sq-42 St: 0.07 miles, 0.26 minutes
# From Times Sq-42 St to 42 St-Bryant Pk: 0.12 miles, 0.41 minutes
# From 42 St-Bryant Pk to 5 Av: 0.14 miles, 0.48 minutes
# From 5 Av to Grand Central-42 St: 0.16 miles, 0.56 minutes
# From Grand Central-42 St to Grand Central-42 St: 0.14 miles, 0.48 minutes
# From Grand Central-42 St to Grand Central-42 St: 0.05 miles, 0.17 minutes
# From Grand Central-42 St to 51 St: 0.45 miles, 1.54 minutes
# From 51 St to Lexington Av/53 St: 0.15 miles, 0.53 minutes
# From Lexington Av/53 St to 5 Av/53 St: 0.37 miles, 1.28 minutes
# From 5 Av/53 St to 59 St-Columbus Circle: 0.66 miles, 2.27 minutes
# From 59 St-Columbus Circle to 59 St-Columbus Circle: 0.01 miles, 0.04 minutes
# From 59 St-Columbus Circle to 66 St-Lincoln Center: 0.36 miles, 1.24 minutes
# From 66 St-Lincoln Center to 72 St: 0.34 miles, 1.17 minutes
# From 72 St to 72 St: 0.35 miles, 1.21 minutes
# From 72 St to 79 St: 0.39 miles, 1.36 minutes
# From 79 St to 86 St: 0.38 miles, 1.31 minutes
# From 86 St to 96 St: 0.42 miles, 1.44 minutes
# From 96 St to 96 St: 0.43 miles, 1.48 minutes
# From 96 St to 103 St: 0.35 miles, 1.21 minutes
# From 103 St to Cathedral Pkwy (110 St): 0.36 miles, 1.23 minutes
# From Cathedral Pkwy (110 St) to Central Park North (110 St): 0.35 miles, 1.20 minutes
# From Central Park North (110 St) to 116 St: 0.24 miles, 0.82 minutes
# From 116 St to 116 St: 0.34 miles, 1.19 minutes
# From 116 St to 125 St: 0.44 miles, 1.51 minutes
# From 125 St to 125 St: 0.43 miles, 1.47 minutes
# From 125 St to 125 St: 0.48 miles, 1.67 minutes
# From 125 St to 116 St: 0.43 miles, 1.50 minutes
# From 116 St to 110 St: 0.28 miles, 0.98 minutes
# From 110 St to 103 St: 0.35 miles, 1.20 minutes
# From 103 St to 96 St: 0.39 miles, 1.34 minutes
# From 96 St to 96 St: 0.23 miles, 0.78 minutes
# From 96 St to 86 St: 0.51 miles, 1.74 minutes
# From 86 St to 86 St: 0.23 miles, 0.78 minutes
# From 86 St to 77 St: 0.46 miles, 1.60 minutes
# From 77 St to 81 St-Museum of Natural History: 0.84 miles, 2.89 minutes
# From 81 St-Museum of Natural History to 86 St: 0.35 miles, 1.21 minutes
# From 86 St to 103 St: 0.94 miles, 3.24 minutes
# From 103 St to Cathedral Pkwy (110 St): 0.32 miles, 1.11 minutes
# From Cathedral Pkwy (110 St) to 116 St-Columbia University: 0.30 miles, 1.02 minutes
# From 116 St-Columbia University to 125 St: 0.62 miles, 2.14 minutes
# From 125 St to 137 St-City College: 0.51 miles, 1.75 minutes
# From 137 St-City College to 145 St: 0.36 miles, 1.24 minutes
# From 145 St to 145 St: 0.34 miles, 1.19 minutes
# From 145 St to 145 St: 0.00 miles, 0.00 minutes
# From 145 St to Harlem-148 St: 0.41 miles, 1.41 minutes
# From Harlem-148 St to 145 St: 0.24 miles, 0.83 minutes
# From 145 St to 149 St-Grand Concourse: 0.49 miles, 1.68 minutes
# From 149 St-Grand Concourse to 149 St-Grand Concourse: 0.03 miles, 0.11 minutes
# From 149 St-Grand Concourse to 138 St-Grand Concourse: 0.39 miles, 1.36 minutes
# From 138 St-Grand Concourse to 3 Av-138 St: 0.27 miles, 0.94 minutes
# From 3 Av-138 St to Brook Av: 0.41 miles, 1.42 minutes
# From Brook Av to Cypress Av: 0.31 miles, 1.07 minutes
# From Cypress Av to E 143 St-St Mary's St: 0.41 miles, 1.40 minutes
# From E 143 St-St Mary's St to E 149 St: 0.30 miles, 1.03 minutes
# From E 149 St to Jackson Av: 0.36 miles, 1.24 minutes
# From Jackson Av to Prospect Av: 0.38 miles, 1.31 minutes
# From Prospect Av to Intervale Av: 0.32 miles, 1.10 minutes
# From Intervale Av to Simpson St: 0.23 miles, 0.80 minutes
# From Simpson St to Hunts Point Av: 0.25 miles, 0.87 minutes
# From Hunts Point Av to Whitlock Av: 0.45 miles, 1.54 minutes
# From Whitlock Av to Freeman St: 0.38 miles, 1.30 minutes
# From Freeman St to 174 St: 0.55 miles, 1.89 minutes
# From 174 St to West Farms Sq-E Tremont Av: 0.45 miles, 1.56 minutes
# From West Farms Sq-E Tremont Av to E 180 St: 0.36 miles, 1.24 minutes
# From E 180 St to Bronx Park East: 0.55 miles, 1.88 minutes
# From Bronx Park East to Morris Park: 0.57 miles, 1.95 minutes
# From Morris Park to Pelham Pkwy: 0.42 miles, 1.44 minutes
# From Pelham Pkwy to Pelham Pkwy: 0.65 miles, 2.25 minutes
# From Pelham Pkwy to Allerton Av: 0.57 miles, 1.97 minutes
# From Allerton Av to Burke Av: 0.41 miles, 1.40 minutes
# From Burke Av to Gun Hill Rd: 0.45 miles, 1.56 minutes
# From Gun Hill Rd to 219 St: 0.46 miles, 1.58 minutes
# From 219 St to 225 St: 0.31 miles, 1.07 minutes
# From 225 St to 233 St: 0.39 miles, 1.34 minutes
# From 233 St to Nereid Av: 0.39 miles, 1.36 minutes
# From Nereid Av to Wakefield-241 St: 0.38 miles, 1.32 minutes
# From Wakefield-241 St to Eastchester-Dyre Av: 1.46 miles, 5.02 minutes
# From Eastchester-Dyre Av to Baychester Av: 0.78 miles, 2.69 minutes
# From Baychester Av to Gun Hill Rd: 0.75 miles, 2.59 minutes
# From Gun Hill Rd to Pelham Bay Park: 1.52 miles, 5.23 minutes
# From Pelham Bay Park to Buhre Av: 0.45 miles, 1.57 minutes
# From Buhre Av to Middletown Rd: 0.28 miles, 0.97 minutes
# From Middletown Rd to Westchester Sq-E Tremont Av: 0.44 miles, 1.52 minutes
# From Westchester Sq-E Tremont Av to Zerega Av: 0.32 miles, 1.10 minutes
# From Zerega Av to Castle Hill Av: 0.27 miles, 0.92 minutes
# From Castle Hill Av to Parkchester: 0.51 miles, 1.75 minutes
# From Parkchester to St Lawrence Av: 0.37 miles, 1.29 minutes
# From St Lawrence Av to Morrison Av-Soundview: 0.39 miles, 1.33 minutes
# From Morrison Av-Soundview to Elder Av: 0.25 miles, 0.87 minutes
# From Elder Av to Longwood Av: 1.25 miles, 4.31 minutes
# From Longwood Av to 3 Av-149 St: 1.11 miles, 3.84 minutes
# From 3 Av-149 St to 161 St-Yankee Stadium: 0.91 miles, 3.15 minutes
# From 161 St-Yankee Stadium to 161 St-Yankee Stadium: 0.01 miles, 0.04 minutes
# From 161 St-Yankee Stadium to 167 St: 0.56 miles, 1.92 minutes
# From 167 St to 167 St: 0.20 miles, 0.68 minutes
# From 167 St to 170 St: 0.37 miles, 1.26 minutes
# From 170 St to 170 St: 0.24 miles, 0.81 minutes
# From 170 St to Mt Eden Av: 0.36 miles, 1.24 minutes
# From Mt Eden Av to 174-175 Sts: 0.26 miles, 0.89 minutes
# From 174-175 Sts to 176 St: 0.20 miles, 0.68 minutes
# From 176 St to Tremont Av: 0.37 miles, 1.27 minutes
# From Tremont Av to Burnside Av: 0.25 miles, 0.85 minutes
# From Burnside Av to 183 St: 0.40 miles, 1.37 minutes
# From 183 St to 182-183 Sts: 0.23 miles, 0.79 minutes
# From 182-183 Sts to Fordham Rd: 0.39 miles, 1.35 minutes
# From Fordham Rd to Fordham Rd: 0.20 miles, 0.69 minutes
# From Fordham Rd to Kingsbridge Rd: 0.40 miles, 1.37 minutes
# From Kingsbridge Rd to Kingsbridge Rd: 0.20 miles, 0.69 minutes
# From Kingsbridge Rd to Bedford Park Blvd-Lehman College: 0.48 miles, 1.65 minutes
# From Bedford Park Blvd-Lehman College to Bedford Park Blvd: 0.15 miles, 0.53 minutes
# From Bedford Park Blvd to Norwood-205 St: 0.45 miles, 1.54 minutes
# From Norwood-205 St to Mosholu Pkwy: 0.46 miles, 1.57 minutes
# From Mosholu Pkwy to Woodlawn: 0.53 miles, 1.84 minutes
# From Woodlawn to Van Cortlandt Park-242 St: 1.06 miles, 3.65 minutes
# From Van Cortlandt Park-242 St to 238 St: 0.34 miles, 1.17 minutes
# From 238 St to 231 St: 0.45 miles, 1.56 minutes
# From 231 St to Marble Hill-225 St: 0.40 miles, 1.36 minutes
# From Marble Hill-225 St to 215 St: 0.45 miles, 1.57 minutes
# From 215 St to Inwood-207 St: 0.26 miles, 0.89 minutes
# From Inwood-207 St to 207 St: 0.24 miles, 0.84 minutes
# From 207 St to Dyckman St: 0.45 miles, 1.54 minutes
# From Dyckman St to Dyckman St: 0.35 miles, 1.22 minutes
# From Dyckman St to 191 St: 0.42 miles, 1.44 minutes
# From 191 St to 190 St: 0.36 miles, 1.25 minutes
# From 190 St to 181 St: 0.54 miles, 1.87 minutes
# From 181 St to 181 St: 0.27 miles, 0.95 minutes
# From 181 St to 175 St: 0.35 miles, 1.21 minutes
# From 175 St to 168 St: 0.46 miles, 1.59 minutes
# From 168 St to 168 St-Washington Hts: 0.03 miles, 0.11 minutes
# From 168 St-Washington Hts to 163 St-Amsterdam Av: 0.31 miles, 1.08 minutes
# From 163 St-Amsterdam Av to 157 St: 0.29 miles, 1.02 minutes
# From 157 St to 155 St: 0.30 miles, 1.04 minutes
# From 155 St to 155 St: 0.17 miles, 0.60 minutes
# From 155 St to 135 St: 0.98 miles, 3.38 minutes
# From 135 St to 135 St: 0.44 miles, 1.52 minutes
# From 135 St to 42 St-Port Authority Bus Terminal: 4.69 miles, 16.18 minutes
# From 42 St-Port Authority Bus Terminal to 34 St-Penn Station: 0.40 miles, 1.37 minutes
# From 34 St-Penn Station to 34 St-Penn Station: 0.18 miles, 0.62 minutes
# From 34 St-Penn Station to 34 St-Herald Sq: 0.17 miles, 0.59 minutes
# From 34 St-Herald Sq to 34 St-Herald Sq: 0.01 miles, 0.04 minutes
# From 34 St-Herald Sq to 28 St: 0.30 miles, 1.02 minutes
# From 28 St to 28 St: 0.27 miles, 0.94 minutes
# From 28 St to 23 St: 0.25 miles, 0.85 minutes
# From 23 St to 23 St: 0.17 miles, 0.59 minutes
# From 23 St to 23 St: 0.21 miles, 0.73 minutes
# From 23 St to 23 St: 0.17 miles, 0.60 minutes
# From 23 St to 28 St: 0.25 miles, 0.87 minutes
# From 28 St to 33 St: 0.24 miles, 0.82 minutes
# From 33 St to 23 St: 0.84 miles, 2.88 minutes
# From 23 St to 18 St: 0.34 miles, 1.16 minutes
# From 18 St to 14 St: 0.20 miles, 0.69 minutes
# From 14 St to 8 Av: 0.09 miles, 0.31 minutes
# From 8 Av to 14 St: 0.18 miles, 0.63 minutes
# From 14 St to 6 Av: 0.18 miles, 0.63 minutes
# From 6 Av to 14 St: 0.07 miles, 0.24 minutes
# From 14 St to 14 St-Union Sq: 0.34 miles, 1.18 minutes
# From 14 St-Union Sq to 14 St-Union Sq: 0.07 miles, 0.23 minutes
# From 14 St-Union Sq to 14 St-Union Sq: 0.04 miles, 0.14 minutes
# From 14 St-Union Sq to 3 Av: 0.24 miles, 0.82 minutes
# From 3 Av to 1 Av: 0.27 miles, 0.93 minutes
# From 1 Av to Astor Pl: 0.50 miles, 1.72 minutes
# From Astor Pl to 8 St-NYU: 0.08 miles, 0.29 minutes
# From 8 St-NYU to Bleecker St: 0.32 miles, 1.11 minutes
# From Bleecker St to Broadway-Lafayette St: 0.09 miles, 0.32 minutes
# From Broadway-Lafayette St to Prince St: 0.10 miles, 0.36 minutes
# From Prince St to Spring St: 0.14 miles, 0.49 minutes
# From Spring St to Bowery: 0.22 miles, 0.76 minutes
# From Bowery to Grand St: 0.14 miles, 0.48 minutes
# From Grand St to Delancey St-Essex St: 0.30 miles, 1.02 minutes
# From Delancey St-Essex St to Delancey St-Essex St: 0.04 miles, 0.14 minutes
# From Delancey St-Essex St to East Broadway: 0.35 miles, 1.20 minutes
# From East Broadway to Canal St: 0.59 miles, 2.04 minutes
# From Canal St to Canal St: 0.04 miles, 0.12 minutes
# From Canal St to Canal St: 0.03 miles, 0.11 minutes
# From Canal St to Canal St: 0.10 miles, 0.33 minutes
# From Canal St to Canal St: 0.20 miles, 0.70 minutes
# From Canal St to Franklin St: 0.14 miles, 0.47 minutes
# From Franklin St to Canal St: 0.25 miles, 0.85 minutes
# From Canal St to Spring St: 0.27 miles, 0.93 minutes
# From Spring St to Houston St: 0.16 miles, 0.56 minutes
# From Houston St to Christopher St-Stonewall: 0.38 miles, 1.31 minutes
# From Christopher St-Stonewall to W 4 St-Wash Sq: 0.15 miles, 0.51 minutes
# From W 4 St-Wash Sq to W 4 St-Wash Sq: 0.00 miles, 0.00 minutes
# From W 4 St-Wash Sq to 2 Av: 0.83 miles, 2.86 minutes
# From 2 Av to Chambers St: 0.99 miles, 3.43 minutes
# From Chambers St to Brooklyn Bridge-City Hall: 0.04 miles, 0.14 minutes
# From Brooklyn Bridge-City Hall to City Hall: 0.15 miles, 0.52 minutes
# From City Hall to Park Place: 0.10 miles, 0.34 minutes
# From Park Place to World Trade Center: 0.06 miles, 0.21 minutes
# From World Trade Center to Chambers St: 0.12 miles, 0.42 minutes
# From Chambers St to Chambers St: 0.10 miles, 0.35 minutes
# From Chambers St to WTC Cortlandt: 0.29 miles, 1.02 minutes
# From WTC Cortlandt to Cortlandt St: 0.10 miles, 0.35 minutes
# From Cortlandt St to Fulton St: 0.08 miles, 0.28 minutes
# From Fulton St to Fulton St: 0.10 miles, 0.33 minutes
# From Fulton St to Fulton St: 0.01 miles, 0.05 minutes
# From Fulton St to Fulton St: 0.08 miles, 0.29 minutes
# From Fulton St to Wall St: 0.22 miles, 0.77 minutes
# From Wall St to Broad St: 0.11 miles, 0.36 minutes
# From Broad St to Wall St: 0.09 miles, 0.30 minutes
# From Wall St to Rector St: 0.08 miles, 0.28 minutes
# From Rector St to Rector St: 0.03 miles, 0.11 minutes
# From Rector St to Bowling Green: 0.19 miles, 0.64 minutes
# From Bowling Green to Whitehall St-South Ferry: 0.13 miles, 0.46 minutes
# From Whitehall St-South Ferry to South Ferry: 0.08 miles, 0.27 minutes
# From South Ferry to Clark St: 1.12 miles, 3.88 minutes
# From Clark St to High St: 0.19 miles, 0.64 minutes
# From High St to York St: 0.24 miles, 0.84 minutes
# From York St to Court St: 0.57 miles, 1.96 minutes
# From Court St to Borough Hall: 0.11 miles, 0.38 minutes
# From Borough Hall to Borough Hall: 0.06 miles, 0.20 minutes
# From Borough Hall to Jay St-MetroTech: 0.15 miles, 0.51 minutes
# From Jay St-MetroTech to Jay St-MetroTech: 0.07 miles, 0.26 minutes
# From Jay St-MetroTech to Hoyt St: 0.12 miles, 0.42 minutes
# From Hoyt St to Hoyt-Schermerhorn Sts: 0.14 miles, 0.49 minutes
# From Hoyt-Schermerhorn Sts to DeKalb Av: 0.22 miles, 0.77 minutes
# From DeKalb Av to Nevins St: 0.18 miles, 0.62 minutes
# From Nevins St to Fulton St: 0.28 miles, 0.96 minutes
# From Fulton St to Lafayette Av: 0.10 miles, 0.35 minutes
# From Lafayette Av to Atlantic Av-Barclays Ctr: 0.19 miles, 0.66 minutes
# From Atlantic Av-Barclays Ctr to Atlantic Av-Barclays Ctr: 0.04 miles, 0.14 minutes
# From Atlantic Av-Barclays Ctr to Atlantic Av-Barclays Ctr: 0.08 miles, 0.26 minutes
# From Atlantic Av-Barclays Ctr to Bergen St: 0.28 miles, 0.95 minutes
# From Bergen St to 7 Av: 0.30 miles, 1.03 minutes
# From 7 Av to Grand Army Plaza: 0.14 miles, 0.49 minutes
# From Grand Army Plaza to Eastern Pkwy-Brooklyn Museum: 0.42 miles, 1.43 minutes
# From Eastern Pkwy-Brooklyn Museum to Botanic Garden: 0.29 miles, 1.01 minutes
# From Botanic Garden to Franklin Av-Medgar Evers College: 0.06 miles, 0.22 minutes
# From Franklin Av-Medgar Evers College to Park Pl: 0.28 miles, 0.98 minutes
# From Park Pl to Franklin Av: 0.41 miles, 1.43 minutes
# From Franklin Av to Franklin Av: 0.08 miles, 0.26 minutes
# From Franklin Av to Nostrand Av: 0.34 miles, 1.18 minutes
# From Nostrand Av to Kingston-Throop Avs: 0.50 miles, 1.73 minutes
# From Kingston-Throop Avs to Utica Av: 0.53 miles, 1.83 minutes
# From Utica Av to Ralph Av: 0.52 miles, 1.80 minutes
# From Ralph Av to Rockaway Av: 0.46 miles, 1.60 minutes
# From Rockaway Av to Chauncey St: 0.32 miles, 1.12 minutes
# From Chauncey St to Halsey St: 0.40 miles, 1.38 minutes
# From Halsey St to Gates Av: 0.37 miles, 1.29 minutes
# From Gates Av to Kosciuszko St: 0.43 miles, 1.48 minutes
# From Kosciuszko St to Central Av: 0.32 miles, 1.11 minutes
# From Central Av to Myrtle Av: 0.44 miles, 1.50 minutes
# From Myrtle Av to Flushing Av: 0.36 miles, 1.23 minutes
# From Flushing Av to Lorimer St: 0.41 miles, 1.42 minutes
# From Lorimer St to Broadway: 0.22 miles, 0.74 minutes
# From Broadway to Hewes St: 0.17 miles, 0.59 minutes
# From Hewes St to Marcy Av: 0.25 miles, 0.86 minutes
# From Marcy Av to Flushing Av: 0.68 miles, 2.34 minutes
# From Flushing Av to Myrtle-Willoughby Avs: 0.41 miles, 1.40 minutes
# From Myrtle-Willoughby Avs to Bedford-Nostrand Avs: 0.41 miles, 1.43 minutes
# From Bedford-Nostrand Avs to Classon Av: 0.35 miles, 1.20 minutes
# From Classon Av to Clinton-Washington Avs: 0.36 miles, 1.24 minutes
# From Clinton-Washington Avs to Clinton-Washington Avs: 0.34 miles, 1.16 minutes
# From Clinton-Washington Avs to Union St: 0.99 miles, 3.43 minutes
# From Union St to 4 Av-9 St: 0.52 miles, 1.80 minutes
# From 4 Av-9 St to 4 Av-9 St: 0.09 miles, 0.30 minutes
# From 4 Av-9 St to Prospect Av: 0.37 miles, 1.29 minutes
# From Prospect Av to 25 St: 0.44 miles, 1.52 minutes
# From 25 St to 36 St: 0.46 miles, 1.59 minutes
# From 36 St to 45 St: 0.55 miles, 1.88 minutes
# From 45 St to 53 St: 0.34 miles, 1.17 minutes
# From 53 St to 59 St: 0.33 miles, 1.12 minutes
# From 59 St to Bay Ridge Av: 0.53 miles, 1.82 minutes
# From Bay Ridge Av to 77 St: 0.38 miles, 1.30 minutes
# From 77 St to 86 St: 0.51 miles, 1.76 minutes
# From 86 St to Bay Ridge-95 St: 0.44 miles, 1.51 minutes
# From Bay Ridge-95 St to 79 St: 1.60 miles, 5.52 minutes
# From 79 St to 18 Av: 0.39 miles, 1.34 minutes
# From 18 Av to 20 Av: 0.30 miles, 1.04 minutes
# From 20 Av to Bay Pkwy: 0.30 miles, 1.03 minutes
# From Bay Pkwy to 25 Av: 0.46 miles, 1.60 minutes
# From 25 Av to Avenue U: 0.40 miles, 1.39 minutes
# From Avenue U to Avenue U: 0.32 miles, 1.10 minutes
# From Avenue U to 86 St: 0.34 miles, 1.19 minutes
# From 86 St to Avenue X: 0.30 miles, 1.03 minutes
# From Avenue X to Bay 50 St: 0.50 miles, 1.73 minutes
# From Bay 50 St to Neptune Av: 0.72 miles, 2.50 minutes
# From Neptune Av to W 8 St-NY Aquarium: 0.34 miles, 1.19 minutes
# From W 8 St-NY Aquarium to Coney Island-Stillwell Av: 0.29 miles, 1.01 minutes
# From Coney Island-Stillwell Av to Ocean Pkwy: 0.67 miles, 2.32 minutes
# From Ocean Pkwy to Brighton Beach: 0.38 miles, 1.33 minutes
# From Brighton Beach to Sheepshead Bay: 0.74 miles, 2.57 minutes
# From Sheepshead Bay to Neck Rd: 0.58 miles, 2.00 minutes
# From Neck Rd to Avenue U: 0.28 miles, 0.98 minutes
# From Avenue U to Kings Hwy: 0.65 miles, 2.26 minutes
# From Kings Hwy to Avenue M: 0.62 miles, 2.15 minutes
# From Avenue M to Avenue J: 0.52 miles, 1.79 minutes
# From Avenue J to Avenue H: 0.30 miles, 1.02 minutes
# From Avenue H to Newkirk Plaza: 0.41 miles, 1.40 minutes
# From Newkirk Plaza to Cortelyou Rd: 0.41 miles, 1.41 minutes
# From Cortelyou Rd to Beverley Rd: 0.22 miles, 0.75 minutes
# From Beverley Rd to Church Av: 0.46 miles, 1.57 minutes
# From Church Av to Parkside Av: 0.34 miles, 1.17 minutes
# From Parkside Av to Prospect Park: 0.44 miles, 1.51 minutes
# From Prospect Park to Sterling St: 0.60 miles, 2.08 minutes
# From Sterling St to President St-Medgar Evers College: 0.36 miles, 1.23 minutes
# From President St-Medgar Evers College to Nostrand Av: 0.14 miles, 0.47 minutes
# From Nostrand Av to Kingston Av: 0.44 miles, 1.50 minutes
# From Kingston Av to Crown Hts-Utica Av: 0.48 miles, 1.67 minutes
# From Crown Hts-Utica Av to Sutter Av-Rutland Rd: 0.61 miles, 2.12 minutes
# From Sutter Av-Rutland Rd to Saratoga Av: 0.40 miles, 1.38 minutes
# From Saratoga Av to Rockaway Av: 0.39 miles, 1.36 minutes
# From Rockaway Av to Junius St: 0.35 miles, 1.20 minutes
# From Junius St to Livonia Av: 0.10 miles, 0.36 minutes
# From Livonia Av to Pennsylvania Av: 0.30 miles, 1.04 minutes
# From Pennsylvania Av to Van Siclen Av: 0.29 miles, 1.01 minutes
# From Van Siclen Av to New Lots Av: 0.28 miles, 0.98 minutes
# From New Lots Av to Shepherd Av: 0.57 miles, 1.97 minutes
# From Shepherd Av to Euclid Av: 0.46 miles, 1.59 minutes
# From Euclid Av to Grant Av: 0.39 miles, 1.34 minutes
# From Grant Av to 80 St: 0.36 miles, 1.23 minutes
# From 80 St to 88 St: 0.40 miles, 1.36 minutes
# From 88 St to Rockaway Blvd: 0.40 miles, 1.38 minutes
# From Rockaway Blvd to 104 St: 0.34 miles, 1.16 minutes
# From 104 St to 111 St: 0.34 miles, 1.18 minutes
# From 111 St to Ozone Park-Lefferts Blvd: 0.35 miles, 1.21 minutes
# From Ozone Park-Lefferts Blvd to Aqueduct Racetrack: 1.06 miles, 3.66 minutes
# From Aqueduct Racetrack to Aqueduct-N Conduit Av: 0.29 miles, 1.01 minutes
# From Aqueduct-N Conduit Av to Howard Beach-JFK Airport: 0.57 miles, 1.97 minutes
# From Howard Beach-JFK Airport to New Lots Av: 3.61 miles, 12.47 minutes
# From New Lots Av to East 105 St: 0.56 miles, 1.94 minutes
# From East 105 St to Canarsie-Rockaway Pkwy: 0.30 miles, 1.03 minutes
# From Canarsie-Rockaway Pkwy to Sutter Av: 1.57 miles, 5.41 minutes
# From Sutter Av to Winthrop St: 2.68 miles, 9.23 minutes
# From Winthrop St to Church Av: 0.40 miles, 1.39 minutes
# From Church Av to Beverly Rd: 0.40 miles, 1.37 minutes
# From Beverly Rd to Newkirk Av-Little Haiti: 0.36 miles, 1.23 minutes
# From Newkirk Av-Little Haiti to Flatbush Av-Brooklyn College: 0.49 miles, 1.70 minutes
# From Flatbush Av-Brooklyn College to 18 Av: 1.55 miles, 5.35 minutes
# From 18 Av to Avenue I: 0.31 miles, 1.07 minutes
# From Avenue I to Bay Pkwy: 0.32 miles, 1.10 minutes
# From Bay Pkwy to Avenue N: 0.39 miles, 1.35 minutes
# From Avenue N to Avenue P: 0.43 miles, 1.49 minutes
# From Avenue P to Kings Hwy: 0.40 miles, 1.37 minutes
# From Kings Hwy to Kings Hwy: 0.42 miles, 1.46 minutes
# From Kings Hwy to Bay Pkwy: 0.55 miles, 1.90 minutes
# From Bay Pkwy to 20 Av: 0.42 miles, 1.45 minutes
# From 20 Av to 18 Av: 0.36 miles, 1.25 minutes
# From 18 Av to New Utrecht Av: 0.42 miles, 1.46 minutes
# From New Utrecht Av to 62 St: 0.12 miles, 0.40 minutes
# From 62 St to 55 St: 0.35 miles, 1.21 minutes
# From 55 St to 50 St: 0.34 miles, 1.16 minutes
# From 50 St to Fort Hamilton Pkwy: 0.32 miles, 1.11 minutes
# From Fort Hamilton Pkwy to 9 Av: 0.37 miles, 1.28 minutes
# From 9 Av to Church Av: 0.78 miles, 2.70 minutes
# From Church Av to Fort Hamilton Pkwy: 0.51 miles, 1.75 minutes
# From Fort Hamilton Pkwy to 15 St-Prospect Park: 0.69 miles, 2.38 minutes
# From 15 St-Prospect Park to 7 Av: 0.41 miles, 1.41 minutes
# From 7 Av to Smith-9 Sts: 0.96 miles, 3.32 minutes
# From Smith-9 Sts to Carroll St: 0.47 miles, 1.61 minutes
# From Carroll St to Bergen St: 0.46 miles, 1.58 minutes
# From Bergen St to Ditmas Av: 3.52 miles, 12.14 minutes
# From Ditmas Av to Fort Hamilton Pkwy: 1.46 miles, 5.04 minutes
# From Fort Hamilton Pkwy to 8 Av: 0.42 miles, 1.45 minutes
# From 8 Av to 71 St: 1.26 miles, 4.36 minutes
# From 71 St to Clifton: 3.81 miles, 13.12 minutes
# From Clifton to Stapleton: 0.50 miles, 1.71 minutes
# From Stapleton to Tompkinsville: 0.62 miles, 2.15 minutes
# From Tompkinsville to St George: 0.47 miles, 1.63 minutes
# From St George to Grasmere: 2.86 miles, 9.86 minutes
# From Grasmere to Old Town: 0.48 miles, 1.66 minutes
# From Old Town to Dongan Hills: 0.71 miles, 2.43 minutes
# From Dongan Hills to Jefferson Av: 0.53 miles, 1.81 minutes
# From Jefferson Av to Grant City: 0.46 miles, 1.59 minutes
# From Grant City to New Dorp: 0.55 miles, 1.88 minutes
# From New Dorp to Oakwood Heights: 0.75 miles, 2.59 minutes
# From Oakwood Heights to Bay Terrace: 0.82 miles, 2.82 minutes
# From Bay Terrace to Great Kills: 0.84 miles, 2.90 minutes
# From Great Kills to Eltingville: 0.83 miles, 2.86 minutes
# From Eltingville to Annadale: 0.77 miles, 2.66 minutes
# From Annadale to Huguenot: 0.85 miles, 2.94 minutes
# From Huguenot to Prince's Bay: 0.71 miles, 2.46 minutes
# From Prince's Bay to Pleasant Plains: 0.96 miles, 3.30 minutes
# From Pleasant Plains to Richmond Valley: 0.62 miles, 2.15 minutes
# From Richmond Valley to Arthur Kill: 0.71 miles, 2.46 minutes
# From Arthur Kill to Tottenville: 0.58 miles, 2.00 minutes
# From Tottenville to 34 St-Hudson Yards: 21.31 miles, 73.48 minutes
# From 34 St-Hudson Yards to Broad Channel: 14.10 miles, 48.62 minutes
# From Broad Channel to Beach 90 St: 1.41 miles, 4.87 minutes
# From Beach 90 St to Beach 98 St: 0.41 miles, 1.41 minutes
# From Beach 98 St to Beach 105 St: 0.39 miles, 1.36 minutes
# From Beach 105 St to Rockaway Park-Beach 116 St: 0.45 miles, 1.55 minutes
# From Rockaway Park-Beach 116 St to Beach 67 St: 2.14 miles, 7.39 minutes
# From Beach 67 St to Beach 60 St: 0.45 miles, 1.56 minutes
# From Beach 60 St to Beach 44 St: 0.66 miles, 2.27 minutes
# From Beach 44 St to Beach 36 St: 0.44 miles, 1.53 minutes
# From Beach 36 St to Beach 25 St: 0.48 miles, 1.66 minutes
# From Beach 25 St to Far Rockaway-Mott Av: 0.41 miles, 1.43 minutes
# Total distance traveled: 253.25 miles
# Total time traveled: 873.26 minutes

# %%
import googlemaps
import pandas as pd
import folium
import polyline
from IPython.display import display

# Your Google Maps API key
API_KEY = 'AIzaSyDmno08HDL11dIRev5_tGNjLUfoOGKfB3g'

# Initialize the Google Maps client
gmaps = googlemaps.Client(key=API_KEY)

def convert_to_optimized_route_format(stations_dict):
    optimized_route = []
    for station in stations_dict:
        optimized_route.append({'name': station['stop_name'], 'lat': station['gtfs_latitude'], 'lng': station['gtfs_longitude']})
    return optimized_route

optimized_route = convert_to_optimized_route_format(stations_dict)
print(optimized_route)

# Function to get the polyline for the path between two points
def get_polyline(start, end, api_key):
    directions_result = gmaps.directions(start, end, mode="transit", transit_mode="subway")
    if directions_result:
        polyline_str = directions_result[0]['overview_polyline']['points']
        return polyline.decode(polyline_str)
    else:
        return []

# Function to plot the entire route
def plot_optimized_route(optimized_route, api_key):
    # Create a Folium map centered around the first station
    first_station = optimized_route[0]
    map_center = (first_station['lat'], first_station['lng'])
    my_map = folium.Map(location=map_center, zoom_start=13)

    # Iterate through the optimized route and plot the path
    for i in range(len(optimized_route) - 1):
        start = (optimized_route[i]['lat'], optimized_route[i]['lng'])
        end = (optimized_route[i + 1]['lat'], optimized_route[i + 1]['lng'])
        path = get_polyline(start, end, api_key)
        
        if path:
            folium.PolyLine(locations=path, color='blue', weight=5, opacity=0.7).add_to(my_map)
        
        # Add markers for the start and end stations
        folium.Marker(location=start, popup=optimized_route[i]['name']).add_to(my_map)
        folium.Marker(location=end, popup=optimized_route[i + 1]['name']).add_to(my_map)

    # Display the map
    display(my_map)

# Plot the optimized route
plot_optimized_route(optimized_route, API_KEY)
# Out:
# [{'name': 'Astoria-Ditmars Blvd', 'lat': '40.775036', 'lng': '-73.912034'}, {'name': 'Astoria Blvd', 'lat': '40.770258', 'lng': '-73.917843'}, {'name': '30 Av', 'lat': '40.766779', 'lng': '-73.921479'}, {'name': 'Broadway', 'lat': '40.76182', 'lng': '-73.925508'}, {'name': '36 Av', 'lat': '40.756804', 'lng': '-73.929575'}, {'name': '39 Av-Dutch Kills', 'lat': '40.752882', 'lng': '-73.932755'}, {'name': 'Lexington Av/59 St', 'lat': '40.76266', 'lng': '-73.967258'}, {'name': '5 Av/59 St', 'lat': '40.764811', 'lng': '-73.973347'}, {'name': '57 St-7 Av', 'lat': '40.764664', 'lng': '-73.980658'}, {'name': '49 St', 'lat': '40.759901', 'lng': '-73.984139'}, {'name': 'Times Sq-42 St', 'lat': '40.754672', 'lng': '-73.986754'}, {'name': '34 St-Herald Sq', 'lat': '40.749567', 'lng': '-73.98795'}, {'name': '28 St', 'lat': '40.745494', 'lng': '-73.988691'}, {'name': '23 St', 'lat': '40.741303', 'lng': '-73.989344'}, {'name': '14 St-Union Sq', 'lat': '40.735736', 'lng': '-73.990568'}, {'name': '8 St-NYU', 'lat': '40.730328', 'lng': '-73.992629'}, {'name': 'Prince St', 'lat': '40.724329', 'lng': '-73.997702'}, {'name': 'Canal St', 'lat': '40.719527', 'lng': '-74.001775'}, {'name': 'Canal St', 'lat': '40.718383', 'lng': '-74.00046'}, {'name': 'City Hall', 'lat': '40.713282', 'lng': '-74.006978'}, {'name': 'Cortlandt St', 'lat': '40.710668', 'lng': '-74.011029'}, {'name': 'Rector St', 'lat': '40.70722', 'lng': '-74.013342'}, {'name': 'Whitehall St-South Ferry', 'lat': '40.703087', 'lng': '-74.012994'}, {'name': 'Court St', 'lat': '40.6941', 'lng': '-73.991777'}, {'name': 'Jay St-MetroTech', 'lat': '40.69218', 'lng': '-73.985942'}, {'name': 'DeKalb Av', 'lat': '40.690635', 'lng': '-73.981824'}, {'name': 'Atlantic Av-Barclays Ctr', 'lat': '40.683666', 'lng': '-73.97881'}, {'name': 'Union St', 'lat': '40.677316', 'lng': '-73.98311'}, {'name': '4 Av-9 St', 'lat': '40.670847', 'lng': '-73.988302'}, {'name': 'Prospect Av', 'lat': '40.665414', 'lng': '-73.992872'}, {'name': '25 St', 'lat': '40.660397', 'lng': '-73.998091'}, {'name': '36 St', 'lat': '40.655144', 'lng': '-74.003549'}, {'name': '45 St', 'lat': '40.648939', 'lng': '-74.010006'}, {'name': '53 St', 'lat': '40.645069', 'lng': '-74.014034'}, {'name': '59 St', 'lat': '40.641362', 'lng': '-74.017881'}, {'name': 'Bay Ridge Av', 'lat': '40.634967', 'lng': '-74.023377'}, {'name': '77 St', 'lat': '40.629742', 'lng': '-74.02551'}, {'name': '86 St', 'lat': '40.622687', 'lng': '-74.028398'}, {'name': 'Bay Ridge-95 St', 'lat': '40.616622', 'lng': '-74.030876'}, {'name': 'Atlantic Av-Barclays Ctr', 'lat': '40.68446', 'lng': '-73.97689'}, {'name': '7 Av', 'lat': '40.67705', 'lng': '-73.972367'}, {'name': 'Prospect Park', 'lat': '40.661614', 'lng': '-73.962246'}, {'name': 'Parkside Av', 'lat': '40.655292', 'lng': '-73.961495'}, {'name': 'Church Av', 'lat': '40.650527', 'lng': '-73.962982'}, {'name': 'Beverley Rd', 'lat': '40.644031', 'lng': '-73.964492'}, {'name': 'Cortelyou Rd', 'lat': '40.640927', 'lng': '-73.963891'}, {'name': 'Newkirk Plaza', 'lat': '40.635082', 'lng': '-73.962793'}, {'name': 'Avenue H', 'lat': '40.62927', 'lng': '-73.961639'}, {'name': 'Avenue J', 'lat': '40.625039', 'lng': '-73.960803'}, {'name': 'Avenue M', 'lat': '40.617618', 'lng': '-73.959399'}, {'name': 'Kings Hwy', 'lat': '40.60867', 'lng': '-73.957734'}, {'name': 'Avenue U', 'lat': '40.5993', 'lng': '-73.955929'}, {'name': 'Neck Rd', 'lat': '40.595246', 'lng': '-73.955161'}, {'name': 'Sheepshead Bay', 'lat': '40.586896', 'lng': '-73.954155'}, {'name': 'Brighton Beach', 'lat': '40.577621', 'lng': '-73.961376'}, {'name': 'Ocean Pkwy', 'lat': '40.576312', 'lng': '-73.968501'}, {'name': 'W 8 St-NY Aquarium', 'lat': '40.576127', 'lng': '-73.975939'}, {'name': 'Coney Island-Stillwell Av', 'lat': '40.577422', 'lng': '-73.981233'}, {'name': '9 Av', 'lat': '40.646292', 'lng': '-73.994324'}, {'name': 'Fort Hamilton Pkwy', 'lat': '40.640914', 'lng': '-73.994304'}, {'name': '50 St', 'lat': '40.63626', 'lng': '-73.994791'}, {'name': '55  ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b9ff7465ac62fdafa0e7223776c145fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b9ff7465ac62fdafa0e7223776c145fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b9ff7465ac62fdafa0e7223776c145fb = L.map(
#                 &quot;map_b9ff7465ac62fdafa0e7223776c145fb&quot;,
#                 {
#                     center: [40.775036, -73.912034],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d353a30ad0eda72f5c03c830e07a31d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d353a30ad0eda72f5c03c830e07a31d6.addTo(map_b9ff7465ac62fdafa0e7223776c145fb);
#
#
#             var poly_line_d1aad506a70101a764490b5605cd1ba3 = L.polyline(
#                 [[40.77501, -73.91211], [40.77499, -73.91208], [40.77026, -73.91785], [40.77022, -73.91789], [40.7702, -73.91785]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_b9ff7465ac62fdafa0e7223776c145fb);
#
#
#             var marker_2eaa394a1188ffdfd6948df19e07fd0c = L.marker(
#                 [40.775036, -73.912034],
#                 {}
#             ).addTo(map_b9ff7465ac62fdafa0e7223776c145fb);
#
#
#         var popup_ce1bb9ffdee5c2577a3958506464f3bb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4add452fecf5ca6a925bbbad003c371a = $(`&lt;div id=&quot;html_4add452fecf5ca6a925bbbad003c371a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Astoria-Ditmars Blvd&lt;/div&gt;`)[0];
#                 popup_ce1bb9ffdee5c2577a3958506464f3bb.setContent(html_4add452fecf5ca6a925bbbad003c371a);
#
#
#
#         marker_2eaa394a1188ffdfd6948df19e07fd0c.bindPopup(popup_ce1bb9ffdee5c2577a3958506464f3bb)
#         ;
#
#
#
#
#             var marker_ad30e6d87ed8997c2e42dd05de9ac950 = L.marker(
#                 [40.770258, -73.917843],
#                 {}
#             ).addTo(map_b9ff7465ac62fdafa0e7223776c145fb);
#
#
#         var popup_2d844ea490de86f70fc5974775a9d97d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_77fd896c5aefc07e01220760016efaf0 = $(`&lt;div id=&quot;html_77fd896c5aefc07e01220760016efaf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Astoria Blvd&lt;/div&gt;`)[0];
#                 popup_2d844ea490de86f70fc5974775a9d97d.setContent(html_77fd896c5aefc07e01220760016efaf0);
#
#
#
#         marker_ad30e6d87ed8997c2e42dd05de9ac950.bindPopup(popup_2d844ea490de86f70fc5974775a9d97d)
#         ;
#
#
#
#
#             var poly_line_d0fffa996732d45812613c09119d7921 = L.polyline(
#                 [[40.7702, -73.91785], [40.77022, -73.91789], [40.76842, -73.91998], [40.76832, -73.9201], [40.76811, -73.92033], [40.76767, -73.92075], [40.76684, -73.92143], [40.76681, -73.92137]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_b9ff7465ac62fdafa0e7223776c145fb);
#
#
#             var marker_10749fc8e85941e0972dce88bcbb1665 = L.marker(
#                 [40.770258, -73.917843],
#                 {}
#             ).addTo(map_b9ff7465ac62fdafa0e7223776c145fb);
#
#
#         var popup_e09691a129dc6df03d6fdebb14df87ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2262b9b05982e7295065b915b84e2822 = $(`&lt;div id=&quot;html_2262b9b05982e7295065b915b84e2822&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Astoria Blvd&lt;/div&gt;`)[0];
#                 popup_e09691a129dc6df03d6fdebb14df87ae.setContent(html_2262b9b05982e7295065b915b84e2822);
#
#
#
#         marker_10749fc8e85941e0972dce88bcbb1665.bindPopup(popup_e09691a129dc6df03d6fdebb14df87ae)
#         ;
#
#
#
#
#             var marker_fc9204a7dc85bb49f4d87fd0911c77f5 = L.marker(
#                 [40.766779, -73.921479],
#                 {
